# %% [markdown]
# # Computing Optical Fiber Modes by `fibermode`

# %% [markdown]
# 1. Step-index fiber
#    - [1.1 Analytic expressions for guided modes](./1_1_stepindex_exact.ipynb)
#    - [1.2 Numerical computation of guided modes](./1_2_stepindex.ipynb)
#    - [1.3 Leaky modes](./1_3_stepindex_leaky.ipynb)
#    - [1.4 Vector guided modes](./1_4_stepindex_vector.ipynb)

# %% [markdown]
# 2. Bragg fiber
#    - [2.1 Semi-analytical methods for leaky modes](./2_1_bragg_exact.ipynb)
#    - [2.2 Numerical computation of leaky modes](./2_2_bragg.ipynb)
#    - [2.3 Adaptive computation of vector leaky modes](./2_3_bragg_adaptivity.ipynb)

# %% [markdown]
# 3. Antiresonant fibers
#    - [3.1 Modes of tube antiresonant fibers (ARF)](./3_1_arf.ipynb)
#    - [3.2 Nested antiresonant nodeless fibers (NANF)](./3_2_nanf.ipynb)
# 4. Photonic bandgap fiber
#    - [4.1 Modes of photonic bandgap fibers](./4_1_pbg.ipynb)
#    - [4.2 All-solid rod-lattice PBG fiber](./4_2_pbg_rod.ipynb)
